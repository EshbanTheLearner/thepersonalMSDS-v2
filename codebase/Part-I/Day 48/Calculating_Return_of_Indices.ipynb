# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI']
ind_data = pd.DataFrame()
for t in tickers:
  ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI
# Date
# 2020-02-26  3116.389893  8980.780273  12774.879883
# 2020-02-27  2978.760010  8566.480469  12367.459961
# 2020-02-28  2954.219971  8567.370117  11890.349609
# 2020-03-02  3090.229980  8952.169922  11857.870117
# 2020-03-03  3004.860107  8687.166016  11985.389648

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6))
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2020-02-26 -0.003779  0.001692 -0.001220
# 2020-02-27 -0.044163 -0.046132 -0.031892
# 2020-02-28 -0.008238  0.000104 -0.038578
# 2020-03-02  0.046039  0.044915 -0.002732
# 2020-03-03 -0.027626 -0.029602  0.010754

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.078027
# ^IXIC     0.112502
# ^GDAXI    0.074368
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']
data_2 = pd.DataFrame()
for t in tickers:
  data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.head()
# Out:
#                    PG        ^GSPC          ^DJI
# Date
# 2007-01-03  43.435204  1416.599976  12474.519531
# 2007-01-04  43.105434  1418.339966  12480.690430
# 2007-01-05  42.735279  1409.709961  12398.009766
# 2007-01-08  42.829502  1412.839966  12423.490234
# 2007-01-09  42.721828  1412.109985  12416.599609

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15, 6))
plt.show()
